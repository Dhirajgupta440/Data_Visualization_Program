# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(0)

# %%
x=np.random.rand(100)
y=2*x+np.random.normal(scale=0.1,size=100)

data=pd.DataFrame({'Feature1':x,'Feature2':y})
data
# Out:
#     Feature1  Feature2
# 0   0.207470  0.484094
# 1   0.424685  0.918846
# 2   0.374170  0.675780
# 3   0.463575  0.788814
# 4   0.277629  0.396964
# ..       ...       ...
# 95  0.379927  0.794819
# 96  0.181151  0.285888
# 97  0.788546  1.433312
# 98  0.056848  0.250149
# 99  0.696997  1.325050
#
# [100 rows x 2 columns]

# %%
sns.scatterplot(data=data,x='Feature1',y='Feature2')
plt.title('Scatter Plot with linera relationship')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.show()
